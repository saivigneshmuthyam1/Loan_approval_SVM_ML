# %%
import pandas as pd

path='train.csv'
try:
    df=pd.read_csv(path, encoding='latin1')
    print(df.head())
    print("-"*90)
except UnicodeDecodeError:
    print("Could not decode the file using 'latin1'. Please try another encoding if you know it.")
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Gender'].dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# # Task
# To analyze the distributions of 'ApplicantIncome' and 'LoanAmount' with respect to 'Loan_Status', we'll start by handling missing values in 'LoanAmount' by imputing them with the median. Then, we will create box plots for both 'ApplicantIncome' and 'LoanAmount' against 'Loan_Status' to visualize their influence on loan approval.
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Handle missing values for LoanAmount by imputing with the median
# if df['LoanAmount'].isnull().any():
#     median_loan_amount = df['LoanAmount'].median()
#     df['LoanAmount'].fillna(median_loan_amount, inplace=True)
#     print(f"Missing values in 'LoanAmount' imputed with median: {median_loan_amount}")
#
# # Visualize 'ApplicantIncome' vs 'Loan_Status'
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='Loan_Status', y='ApplicantIncome', data=df)
# plt.title('Applicant Income Distribution by Loan Status')
# plt.xlabel('Loan Status')
# plt.ylabel('Applicant Income')
# plt.show()
#
# # Visualize 'LoanAmount' vs 'Loan_Status'
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='Loan_Status', y='LoanAmount', data=df)
# plt.title('Loan Amount Distribution by Loan Status')
# plt.xlabel('Loan Status')
# plt.ylabel('Loan Amount')
# plt.show()
# ```

# %% [markdown]
# ## Analyze Applicant Income and Loan Amount
#
# ### Subtask:
# Visualize the distributions of 'ApplicantIncome' and 'LoanAmount' with respect to 'Loan_Status' using box plots to understand their influence on loan approval. Missing values in 'LoanAmount' will be handled by imputing with the median.

# %% [markdown]
# **Reasoning**:
# The first step is to check for missing values in the 'LoanAmount' column, calculate its median if missing values exist, and then impute them as per the instructions.

# %%
if df['LoanAmount'].isnull().any():
    median_loan_amount = df['LoanAmount'].median()
    df['LoanAmount'].fillna(median_loan_amount, inplace=True)
    print(f"Missing values in 'LoanAmount' imputed with median: {median_loan_amount}")
else:
    print("No missing values found in 'LoanAmount'.")

df.isna().sum()
# Out:
# Missing values in 'LoanAmount' imputed with median: 128.0
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# **Reasoning**:
# The previous step successfully imputed missing values in 'LoanAmount'. The next step, as per the instructions, is to visualize the distributions of 'ApplicantIncome' and 'LoanAmount' with respect to 'Loan_Status' using box plots to understand their influence on loan approval.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'ApplicantIncome' vs 'Loan_Status'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Loan_Status', y='ApplicantIncome', data=df)
plt.title('Applicant Income Distribution by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Applicant Income')
plt.show()

# Visualize 'LoanAmount' vs 'Loan_Status'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Loan_Status', y='LoanAmount', data=df)
plt.title('Loan Amount Distribution by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Loan Amount')
plt.show()

# %% [markdown]
# ## Analyze Credit History
#
# ### Subtask:
# Examine the relationship between 'Credit_History' and 'Loan_Status' using a count plot or stacked bar chart to see how credit history affects approval decisions. Missing values in this column will be handled for visualization.

# %% [markdown]
# **Reasoning**:
# The first step is to check for missing values in the 'Credit_History' column as instructed, before proceeding with imputation and visualization.

# %%
print(f"Missing values in 'Credit_History': {df['Credit_History'].isnull().sum()}")
# Out:
# Missing values in 'Credit_History': 50

# %% [markdown]
# **Reasoning**:
# As per the instructions, missing values in the 'Credit_History' column need to be imputed with the mode of that column to prepare for visualization.

# %%
if df['Credit_History'].isnull().any():
    mode_credit_history = df['Credit_History'].mode()[0]
    df['Credit_History'].fillna(mode_credit_history, inplace=True)
    print(f"Missing values in 'Credit_History' imputed with mode: {mode_credit_history}")
else:
    print("No missing values found in 'Credit_History'.")

df.isna().sum()
# Out:
# Missing values in 'Credit_History' imputed with mode: 1.0
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# **Reasoning**:
# The previous cell generated a `FutureWarning` regarding `inplace=True`. To prevent this warning and adhere to best practices, the `fillna` operation should be updated to assign the result back to the column directly. After ensuring missing values are correctly handled, the next step is to create a count plot to visualize the relationship between 'Credit_History' and 'Loan_Status', as specified in the subtask.

# %%
if df['Credit_History'].isnull().any():
    mode_credit_history = df['Credit_History'].mode()[0]
    df['Credit_History'] = df['Credit_History'].fillna(mode_credit_history)
    print(f"Missing values in 'Credit_History' imputed with mode: {mode_credit_history}")
else:
    print("No missing values found in 'Credit_History'.")

import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Credit_History' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Credit_History', hue='Loan_Status', data=df)
plt.title('Loan Status by Credit History')
plt.xlabel('Credit History (1=Yes, 0=No)')
plt.ylabel('Number of Applicants')
plt.show()
# Out:
# No missing values found in 'Credit_History'.

# %% [markdown]
# ## Analyze Employment Status and Other Categorical Features
#
# ### Subtask:
# Investigate the impact of 'Self_Employed' (as a proxy for employment status), 'Gender', 'Married', 'Dependents', 'Education', and 'Property_Area' on 'Loan_Status' using count plots or stacked bar charts. Missing values in these columns will be handled for visualization.

# %% [markdown]
# **Reasoning**:
# The first instruction is to check for missing values in the 'Gender' column, then impute them with the mode if they exist. The `df.isna().sum()` output confirms that 'Gender' has missing values.

# %%
if df['Gender'].isnull().any():
    mode_gender = df['Gender'].mode()[0]
    df['Gender'] = df['Gender'].fillna(mode_gender)
    print(f"Missing values in 'Gender' imputed with mode: {mode_gender}")
else:
    print("No missing values found in 'Gender'.")

print(f"Remaining missing values in 'Gender': {df['Gender'].isnull().sum()}")
# Out:
# Missing values in 'Gender' imputed with mode: Male
# Remaining missing values in 'Gender': 0

# %% [markdown]
# **Reasoning**:
# The previous step successfully handled missing values in the 'Gender' column. The next instruction is to create a count plot to visualize the relationship between 'Gender' and 'Loan_Status' as specified in the subtask.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Gender' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Reasoning**:
# Following the subtask instructions, the next step is to repeat step 1 for the 'Married' column, which involves checking for missing values and imputing them with the mode.

# %%
if df['Married'].isnull().any():
    mode_married = df['Married'].mode()[0]
    df['Married'] = df['Married'].fillna(mode_married)
    print(f"Missing values in 'Married' imputed with mode: {mode_married}")
else:
    print("No missing values found in 'Married'.")

print(f"Remaining missing values in 'Married': {df['Married'].isnull().sum()}")
# Out:
# Missing values in 'Married' imputed with mode: Yes
# Remaining missing values in 'Married': 0

# %% [markdown]
# **Reasoning**:
# The previous step successfully handled missing values in the 'Married' column. The next instruction is to create a count plot to visualize the relationship between 'Married' and 'Loan_Status' as specified in the subtask.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Married' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Married', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Marital Status')
plt.xlabel('Married')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Reasoning**:
# Following the subtask instructions, the next step is to repeat step 1 for the 'Dependents' column, which involves checking for missing values and imputing them with the mode.

# %%
if df['Dependents'].isnull().any():
    mode_dependents = df['Dependents'].mode()[0]
    df['Dependents'] = df['Dependents'].fillna(mode_dependents)
    print(f"Missing values in 'Dependents' imputed with mode: {mode_dependents}")
else:
    print("No missing values found in 'Dependents'.")

print(f"Remaining missing values in 'Dependents': {df['Dependents'].isnull().sum()}")
# Out:
# Missing values in 'Dependents' imputed with mode: 0
# Remaining missing values in 'Dependents': 0

# %% [markdown]
# **Reasoning**:
# The previous step successfully handled missing values in the 'Dependents' column. The next instruction is to create a count plot to visualize the relationship between 'Dependents' and 'Loan_Status' as specified in the subtask.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Dependents' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Dependents', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Number of Dependents')
plt.xlabel('Number of Dependents')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Reasoning**:
# Following the subtask instructions, the next step is to repeat step 1 for the 'Self_Employed' column, which involves checking for missing values and imputing them with the mode.

# %%
if df['Self_Employed'].isnull().any():
    mode_self_employed = df['Self_Employed'].mode()[0]
    df['Self_Employed'] = df['Self_Employed'].fillna(mode_self_employed)
    print(f"Missing values in 'Self_Employed' imputed with mode: {mode_self_employed}")
else:
    print("No missing values found in 'Self_Employed'.")

print(f"Remaining missing values in 'Self_Employed': {df['Self_Employed'].isnull().sum()}")
# Out:
# Missing values in 'Self_Employed' imputed with mode: No
# Remaining missing values in 'Self_Employed': 0

# %% [markdown]
# **Reasoning**:
# The previous step successfully handled missing values in the 'Self_Employed' column. The next instruction is to create a count plot to visualize the relationship between 'Self_Employed' and 'Loan_Status' as specified in the subtask.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Self_Employed' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Self_Employed', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Self-Employment Status')
plt.xlabel('Self-Employed')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Reasoning**:
# The previous step visualized 'Self_Employed' vs 'Loan_Status'. As per the subtask, the next instruction is to create a count plot to visualize the relationship between 'Education' and 'Loan_Status', without needing to handle missing values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Education' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Education', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Education Level')
plt.xlabel('Education')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# **Reasoning**:
# The previous step visualized 'Education' vs 'Loan_Status'. As per the subtask, the next instruction is to create a count plot to visualize the relationship between 'Property_Area' and 'Loan_Status', without needing to handle missing values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize 'Property_Area' vs 'Loan_Status'
plt.figure(figsize=(8, 6))
sns.countplot(x='Property_Area', hue='Loan_Status', data=df, palette='viridis')
plt.title('Loan Status by Property Area')
plt.xlabel('Property Area')
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# ## Identify Influential Features
#
# ### Subtask:
# Based on the visualizations, summarize which features appear to have the most significant influence on loan approval.

# %% [markdown]
# ### Influential Features on Loan Approval
#
# Based on the visualizations, the following features appear to have the most significant influence on loan approval:
#
# 1.  **Credit_History**: This is by far the most influential feature. The count plot clearly shows that applicants with a `Credit_History` of 1 (indicating a good credit history) have a significantly higher proportion of approved loans compared to those with a `Credit_History` of 0.
#
# 2.  **Property_Area**: The count plot for `Property_Area` versus `Loan_Status` indicates that applicants from **Semiurban** areas have a notably higher loan approval rate than those from Rural or Urban areas. This suggests that the location of the property plays a role in approval decisions.
#
# 3.  **Education**: The count plot reveals that **Graduates** tend to have a higher proportion of approved loans compared to those who are Not Graduate. This implies that educational background might be a factor in loan approval.
#
# 4.  **Married**: The visualization suggests that **Married** applicants have a higher number of approved loans, and potentially a higher approval rate, compared to unmarried applicants. This could be an influential factor.
#
# 5.  **ApplicantIncome** and **LoanAmount**: While the box plots for `ApplicantIncome` and `LoanAmount` show some differences in distribution between approved and rejected loans (e.g., approved loans might have slightly higher median income/amount), the overlap is substantial, making their individual influence less clear-cut than the categorical features above. However, higher income and reasonable loan amounts are generally correlated with approval.
#
# Features like `Gender`, `Dependents`, and `Self_Employed` did not show as strong or distinct a pattern in their relationship with `Loan_Status` compared to the others, meaning their individual influence on loan approval might be less pronounced based on these visualizations alone.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide a comprehensive summary of the identified features and their potential influence on loan approval, along with any initial insights from the analysis.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Missing Value Imputation:** Missing values in 'LoanAmount' were successfully imputed with the median of 128.0. Missing values in 'Credit_History' were imputed with the mode of 1.0. For categorical features like 'Gender', 'Married', 'Dependents', and 'Self_Employed', missing values were imputed with their respective modes ('Male', 'Yes', '0', 'No').
# *   **Credit History is the Most Influential Factor:** Applicants with a positive credit history (Credit\_History = 1) show a significantly higher rate of loan approval compared to those with a negative credit history.
# *   **Property Area Impacts Approval:** Applicants from 'Semiurban' areas have a notably higher loan approval rate than those from 'Rural' or 'Urban' areas.
# *   **Education Correlates with Approval:** Graduates tend to have a higher proportion of approved loans compared to applicants who are 'Not Graduate'.
# *   **Marital Status Shows Influence:** Married applicants appear to have a higher number of approved loans, suggesting a potential positive correlation with loan approval.
# *   **Applicant Income and Loan Amount:** While box plots showed some distributional differences between approved and rejected loans, the substantial overlap in income and loan amounts indicates their individual influence might be less distinct compared to certain categorical features. Higher income and reasonable loan amounts are generally correlated with approval.
# *   **Limited Influence from Other Features:** Features such as 'Gender', 'Dependents', and 'Self_Employed' did not exhibit strong, distinct patterns or clear correlations with loan approval status based on the visualizations.
#
# ### Insights or Next Steps
#
# *   Prioritize a positive credit history and property in a semiurban area as critical eligibility criteria for loan approval, given their strong observed influence.
# *   Further investigate the interplay between 'ApplicantIncome', 'LoanAmount', and 'Loan_Status' by perhaps segmenting the data or performing feature engineering (e.g., debt-to-income ratio) to uncover more nuanced relationships beyond simple distributions.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np

# Make a copy to avoid modifying the original DataFrame further if df is used elsewhere
df_processed = df.copy()

# Drop Loan_ID as it's an identifier and not a feature for modeling
df_processed = df_processed.drop('Loan_ID', axis=1)

# Impute missing values for 'Loan_Amount_Term' with the mode
# We already handled other missing values in previous steps.
if df_processed['Loan_Amount_Term'].isnull().any():
    mode_loan_amount_term = df_processed['Loan_Amount_Term'].mode()[0]
    df_processed['Loan_Amount_Term'] = df_processed['Loan_Amount_Term'].fillna(mode_loan_amount_term)
    print(f"Missing values in 'Loan_Amount_Term' imputed with mode: {mode_loan_amount_term}")

# Convert 'Loan_Status' to numerical (0 or 1)
le = LabelEncoder()
df_processed['Loan_Status'] = le.fit_transform(df_processed['Loan_Status'])

# Separate features (X) and target (y)
X = df_processed.drop('Loan_Status', axis=1)
y = df_processed['Loan_Status']

# Identify categorical and numerical columns for preprocessing
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns

# Create preprocessing pipelines for numerical and categorical features
numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Create a column transformer to apply different transformations to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Apply preprocessing and split data into training and testing sets
X_preprocessed = preprocessor.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# Train SVM with Linear Kernel
svm_linear = SVC(kernel='linear', C=1)
svm_linear.fit(X_train, y_train)
y_pred_linear = svm_linear.predict(X_test)

# Train SVM with Polynomial Kernel
svm_poly = SVC(kernel='poly', degree=3, C=1)
svm_poly.fit(X_train, y_train)
y_pred_poly = svm_poly.predict(X_test)

# Train SVM with RBF Kernel
svm_rbf = SVC(kernel='rbf', C=1, gamma='scale')
svm_rbf.fit(X_train, y_train)
y_pred_rbf = svm_rbf.predict(X_test)
# Out:
# Missing values in 'Loan_Amount_Term' imputed with mode: 360.0

# %% [markdown]
# # Task
# ## Evaluate and Compare SVM Models
#
# ### Subtask:
# Calculate and display the accuracy, precision, and recall for the SVM model trained with a linear kernel using the test set. Then, repeat this for the polynomial and RBF kernel SVM models. Finally, summarize and compare the performance of all three SVM models.
#
# ### Reasoning:
# The previous step successfully trained SVM models with linear, polynomial, and RBF kernels and obtained predictions on the test set. The next logical step is to evaluate these models using standard classification metrics: accuracy, precision, and recall. This will allow for a quantitative comparison of their performance, as outlined in the plan. We will use `sklearn.metrics` for this purpose.
#
# For each kernel, we will:
# 1.  Calculate `accuracy_score`.
# 2.  Calculate `precision_score`.
# 3.  Calculate `recall_score`.
# 4.  Print these metrics.
# After evaluating each model, we will provide a comprehensive summary and comparison to identify the best-performing kernel.

# %% [markdown]
# ## Evaluate Linear SVM
#
# ### Subtask:
# Calculate and display the accuracy, precision, and recall for the SVM model trained with a linear kernel using the test set.

# %% [markdown]
# **Reasoning**:
# First, I will import the necessary metrics from `sklearn.metrics` to evaluate the linear SVM model.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy for the linear SVM model
accuracy_linear = accuracy_score(y_test, y_pred_linear)

# Calculate precision for the linear SVM model
precision_linear = precision_score(y_test, y_pred_linear)

# Calculate recall for the linear SVM model
recall_linear = recall_score(y_test, y_pred_linear)

# Print the evaluation metrics
print(f"Linear SVM Model Accuracy: {accuracy_linear:.4f}")
print(f"Linear SVM Model Precision: {precision_linear:.4f}")
print(f"Linear SVM Model Recall: {recall_linear:.4f}")
# Out:
# Linear SVM Model Accuracy: 0.7886
# Linear SVM Model Precision: 0.7596
# Linear SVM Model Recall: 0.9875

# %% [markdown]
# ## Evaluate Polynomial SVM
#
# ### Subtask:
# Calculate and display the accuracy, precision, and recall for the SVM model trained with a polynomial kernel using the test set.

# %% [markdown]
# **Reasoning**:
# The previous markdown block introduced the subtask for evaluating the polynomial SVM. Now, I will calculate and print the accuracy, precision, and recall for the polynomial SVM model using the predictions `y_pred_poly` and the true labels `y_test`.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy for the polynomial SVM model
accuracy_poly = accuracy_score(y_test, y_pred_poly)

# Calculate precision for the polynomial SVM model
precision_poly = precision_score(y_test, y_pred_poly)

# Calculate recall for the polynomial SVM model
recall_poly = recall_score(y_test, y_pred_poly)

# Print the evaluation metrics
print(f"Polynomial SVM Model Accuracy: {accuracy_poly:.4f}")
print(f"Polynomial SVM Model Precision: {precision_poly:.4f}")
print(f"Polynomial SVM Model Recall: {recall_poly:.4f}")
# Out:
# Polynomial SVM Model Accuracy: 0.7805
# Polynomial SVM Model Precision: 0.7573
# Polynomial SVM Model Recall: 0.9750

# %% [markdown]
# ## Evaluate RBF SVM
#
# ### Subtask:
# Calculate and display the accuracy, precision, and recall for the SVM model trained with an RBF kernel using the test set.

# %% [markdown]
# **Reasoning**:
# The previous markdown block introduced the subtask for evaluating the RBF SVM. Now, I will calculate and print the accuracy, precision, and recall for the RBF SVM model using the predictions `y_pred_rbf` and the true labels `y_test`.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy for the RBF SVM model
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)

# Calculate precision for the RBF SVM model
precision_rbf = precision_score(y_test, y_pred_rbf)

# Calculate recall for the RBF SVM model
recall_rbf = recall_score(y_test, y_pred_rbf)

# Print the evaluation metrics
print(f"RBF SVM Model Accuracy: {accuracy_rbf:.4f}")
print(f"RBF SVM Model Precision: {precision_rbf:.4f}")
print(f"RBF SVM Model Recall: {recall_rbf:.4f}")
# Out:
# RBF SVM Model Accuracy: 0.7886
# RBF SVM Model Precision: 0.7596
# RBF SVM Model Recall: 0.9875

# %% [markdown]
# ## Summarize and Compare SVM Models
#
# ### Subtask:
# Summarize and compare the performance of all three SVM models (linear, polynomial, and RBF) based on their accuracy, precision, and recall metrics.

# %% [markdown]
# ### SVM Model Performance Summary
#
# After evaluating the Support Vector Machine (SVM) models with different kernels, here's a summary of their performance on the test set:
#
# | Model Kernel | Accuracy | Precision | Recall |
# |--------------|----------|-----------|--------|
# | Linear       | 0.7886   | 0.7596    | 0.9875 |
# | Polynomial   | 0.7805   | 0.7573    | 0.9750 |
# | RBF          | 0.7886   | 0.7596    | 0.9875 |
#
# ### Comparison:
#
# *   **Accuracy:** Both the **Linear** and **RBF** kernels achieved the highest accuracy of 0.7886, slightly outperforming the Polynomial kernel (0.7805).
# *   **Precision:** Similarly, the **Linear** and **RBF** kernels also showed identical precision scores of 0.7596, which is marginally better than the Polynomial kernel (0.7573).
# *   **Recall:** The **Linear** and **RBF** kernels again had identical recall scores of 0.9875, indicating they were very effective at identifying positive cases (loan approvals). The Polynomial kernel had a slightly lower recall of 0.9750.
#
# ### Conclusion:
#
# Based on these metrics, both the **Linear SVM** and **RBF SVM** models performed equally well across accuracy, precision, and recall, making them the better choices for this particular dataset and classification task. The Polynomial SVM model showed slightly lower performance in all evaluated metrics.

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Summarize and compare the accuracy, precision, and recall of all three SVM models (Linear, Polynomial, RBF kernels). Discuss which kernel appears to handle non-linear patterns better and which generalizes best on unseen data based on these metrics.

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Summarize and compare the accuracy, precision, and recall of all three SVM models (Linear, Polynomial, RBF kernels). Discuss which kernel appears to handle non-linear patterns better and which generalizes best on unseen data based on these metrics.
#
# ### SVM Model Performance Summary
#
# | Model Kernel | Accuracy | Precision | Recall |
# |--------------|----------|-----------|--------|
# | Linear       | 0.7886   | 0.7596    | 0.9875 |
# | Polynomial   | 0.7805   | 0.7573    | 0.9750 |
# | RBF          | 0.7886   | 0.7596    | 0.9875 |
#
# ### Comparison and Discussion
#
# Based on the evaluation metrics, we can observe the following:
#
# *   **Accuracy**: Both the Linear and RBF kernel SVM models achieved the highest accuracy of 0.7886. The Polynomial kernel model performed slightly worse with an accuracy of 0.7805.
#
# *   **Precision**: Similar to accuracy, the Linear and RBF kernel models show the highest precision at 0.7596, indicating a slightly better ability to correctly identify positive instances among all predicted positives. The Polynomial kernel has a marginally lower precision of 0.7573.
#
# *   **Recall**: All three models achieved very high recall scores, with Linear and RBF again leading at 0.9875, and Polynomial slightly behind at 0.9750. This indicates that all models are very good at identifying most of the actual positive cases (loan approvals).
#
# **Insights on Kernel Performance:**
#
# It appears that for this particular dataset, the **Linear and RBF kernels perform very similarly and slightly better than the Polynomial kernel** across all three metrics (accuracy, precision, and recall). Both Linear and RBF kernels achieved identical top scores. Given the high recall and decent precision for a classification task like loan approval, where identifying actual approvals is crucial, all models are performing reasonably well, especially the Linear and RBF ones.
#
# The fact that a simple **Linear kernel performs as well as the more complex RBF kernel** suggests that the dataset might be largely linearly separable, or the non-linear patterns are not very complex or strong enough to be significantly captured by the RBF kernel with its current hyperparameters. The Polynomial kernel, with `degree=3`, showed slightly inferior performance, which might indicate that this specific non-linear transformation did not fit the data as well.
#
# For practical deployment, a simpler model like the **Linear SVM** might be preferred due to its interpretability and potentially faster training/prediction times, especially if its performance is comparable to more complex models. There is no strong evidence here to suggest that a non-linear kernel (Polynomial or RBF) significantly *outperforms* the linear kernel in handling non-linear patterns for this specific problem, at least with the current hyperparameter settings. Both Linear and RBF generalize equally well on this unseen data based on these metrics.

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Summarize and compare the accuracy, precision, and recall of all three SVM models (Linear, Polynomial, RBF kernels). Discuss which kernel appears to handle non-linear patterns better and which generalizes best on unseen data based on these metrics.
#
# ### SVM Model Performance Summary
#
# | Model Kernel | Accuracy | Precision | Recall |
# |--------------|----------|-----------|--------|
# | Linear       | 0.7886   | 0.7596    | 0.9875 |
# | Polynomial   | 0.7805   | 0.7573    | 0.9750 |
# | RBF          | 0.7886   | 0.7596    | 0.9875 |
#
# ### Comparison and Discussion
#
# Based on the evaluation metrics, we can observe the following:
#
# *   **Accuracy**: Both the Linear and RBF kernel SVM models achieved the highest accuracy of 0.7886. The Polynomial kernel model performed slightly worse with an accuracy of 0.7805.
#
# *   **Precision**: Similar to accuracy, the Linear and RBF kernel models show the highest precision at 0.7596, indicating a slightly better ability to correctly identify positive instances among all predicted positives. The Polynomial kernel has a marginally lower precision of 0.7573.
#
# *   **Recall**: All three models achieved very high recall scores, with Linear and RBF again leading at 0.9875, and Polynomial slightly behind at 0.9750. This indicates that all models are very good at identifying most of the actual positive cases (loan approvals).
#
# **Insights on Kernel Performance:**
#
# It appears that for this particular dataset, the **Linear and RBF kernels perform very similarly and slightly better than the Polynomial kernel** across all three metrics (accuracy, precision, and recall). Both Linear and RBF kernels achieved identical top scores. Given the high recall and decent precision for a classification task like loan approval, where identifying actual approvals is crucial, all models are performing reasonably well, especially the Linear and RBF ones.
#
# The fact that a simple **Linear kernel performs as well as the more complex RBF kernel** suggests that the dataset might be largely linearly separable, or the non-linear patterns are not very complex or strong enough to be significantly captured by the RBF kernel with its current hyperparameters. The Polynomial kernel, with `degree=3`, showed slightly inferior performance, which might indicate that this specific non-linear transformation did not fit the data as well.
#
# For practical deployment, a simpler model like the **Linear SVM** might be preferred due to its interpretability and potentially faster training/prediction times, especially if its performance is comparable to more complex models. There is no strong evidence here to suggest that a non-linear kernel (Polynomial or RBF) significantly *outperforms* the linear kernel in handling non-linear patterns for this specific problem, at least with the current hyperparameter settings. Both Linear and RBF generalize equally well on this unseen data based on these metrics.

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Summarize and compare the accuracy, precision, and recall of all three SVM models (Linear, Polynomial, RBF kernels). Discuss which kernel appears to handle non-linear patterns better and which generalizes best on unseen data based on these metrics.
#
# ### SVM Model Performance Summary
#
# | Model Kernel | Accuracy | Precision | Recall |
# |--------------|----------|-----------|--------|
# | Linear       | 0.7886   | 0.7596    | 0.9875 |
# | Polynomial   | 0.7805   | 0.7573    | 0.9750 |
# | RBF          | 0.7886   | 0.7596    | 0.9875 |
#
# ### Comparison and Discussion
#
# Based on the evaluation metrics, we can observe the following:
#
# *   **Accuracy**: Both the Linear and RBF kernel SVM models achieved the highest accuracy of 0.7886. The Polynomial kernel model performed slightly worse with an accuracy of 0.7805.
#
# *   **Precision**: Similar to accuracy, the Linear and RBF kernel models show the highest precision at 0.7596, indicating a slightly better ability to correctly identify positive instances among all predicted positives. The Polynomial kernel has a marginally lower precision of 0.7573.
#
# *   **Recall**: All three models achieved very high recall scores, with Linear and RBF again leading at 0.9875, and Polynomial slightly behind at 0.9750. This indicates that all models are very good at identifying most of the actual positive cases (loan approvals).
#
# **Insights on Kernel Performance:**
#
# It appears that for this particular dataset, the **Linear and RBF kernels perform very similarly and slightly better than the Polynomial kernel** across all three metrics (accuracy, precision, and recall). Both Linear and RBF kernels achieved identical top scores. Given the high recall and decent precision for a classification task like loan approval, where identifying actual approvals is crucial, all models are performing reasonably well, especially the Linear and RBF ones.
#
# The fact that a simple **Linear kernel performs as well as the more complex RBF kernel** suggests that the dataset might be largely linearly separable, or the non-linear patterns are not very complex or strong enough to be significantly captured by the RBF kernel with its current hyperparameters. The Polynomial kernel, with `degree=3`, showed slightly inferior performance, which might indicate that this specific non-linear transformation did not fit the data as well.
#
# For practical deployment, a simpler model like the **Linear SVM** might be preferred due to its interpretability and potentially faster training/prediction times, especially if its performance is comparable to more complex models. There is no strong evidence here to suggest that a non-linear kernel (Polynomial or RBF) significantly *outperforms* the linear kernel in handling non-linear patterns for this specific problem, at least with the current hyperparameter settings. Both Linear and RBF generalize equally well on this unseen data based on these metrics.

# %% [markdown]
# ## Compare Model Performance
#
# ### Subtask:
# Summarize and compare the accuracy, precision, and recall of all three SVM models (Linear, Polynomial, RBF kernels). Discuss which kernel appears to handle non-linear patterns better and which generalizes best on unseen data based on these metrics.
#
# ### SVM Model Performance Summary
#
# | Model Kernel | Accuracy | Precision | Recall |
# |--------------|----------|-----------|--------|
# | Linear       | 0.7886   | 0.7596    | 0.9875 |
# | Polynomial   | 0.7805   | 0.7573    | 0.9750 |
# | RBF          | 0.7886   | 0.7596    | 0.9875 |
#
# ### Comparison and Discussion
#
# Based on the evaluation metrics, we can observe the following:
#
# *   **Accuracy**: Both the Linear and RBF kernel SVM models achieved the highest accuracy of 0.7886. The Polynomial kernel model performed slightly worse with an accuracy of 0.7805.
#
# *   **Precision**: Similar to accuracy, the Linear and RBF kernel models show the highest precision at 0.7596, indicating a slightly better ability to correctly identify positive instances among all predicted positives. The Polynomial kernel has a marginally lower precision of 0.7573.
#
# *   **Recall**: All three models achieved very high recall scores, with Linear and RBF again leading at 0.9875, and Polynomial slightly behind at 0.9750. This indicates that all models are very good at identifying most of the actual positive cases (loan approvals).
#
# **Insights on Kernel Performance:**
#
# It appears that for this particular dataset, the **Linear and RBF kernels perform very similarly and slightly better than the Polynomial kernel** across all three metrics (accuracy, precision, and recall). Both Linear and RBF kernels achieved identical top scores. Given the high recall and decent precision for a classification task like loan approval, where identifying actual approvals is crucial, all models are performing reasonably well, especially the Linear and RBF ones.
#
# The fact that a simple **Linear kernel performs as well as the more complex RBF kernel** suggests that the dataset might be largely linearly separable, or the non-linear patterns are not very complex or strong enough to be significantly captured by the RBF kernel with its current hyperparameters. The Polynomial kernel, with `degree=3`, showed slightly inferior performance, which might indicate that this specific non-linear transformation did not fit the data as well.
#
# For practical deployment, a simpler model like the **Linear SVM** might be preferred due to its interpretability and potentially faster training/prediction times, especially if its performance is comparable to more complex models. There is no strong evidence here to suggest that a non-linear kernel (Polynomial or RBF) significantly *outperforms* the linear kernel in handling non-linear patterns for this specific problem, at least with the current hyperparameter settings. Both Linear and RBF generalize equally well on this unseen data based on these metrics.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide a comprehensive summary of the SVM model comparison, highlighting the best-performing kernel and its implications for the loan approval prediction system.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The best-performing kernels for the loan approval prediction system are both the Linear and RBF (Radial Basis Function) kernels, as they achieved identical and superior performance across all evaluated metrics compared to the Polynomial kernel. For practical deployment, the Linear SVM is often preferred due to its simplicity, interpretability, and potentially faster processing times, especially when its performance is comparable to more complex models like RBF.
#
# ### Data Analysis Key Findings
# *   The Linear and RBF SVM models achieved the highest accuracy, precision, and recall scores:
#     *   Accuracy: 0.7886
#     *   Precision: 0.7596
#     *   Recall: 0.9875
# *   The Polynomial SVM model performed slightly worse across all metrics:
#     *   Accuracy: 0.7805
#     *   Precision: 0.7573
#     *   Recall: 0.9750
# *   Both Linear and RBF kernels demonstrated identical performance, suggesting that for this dataset, either the data is largely linearly separable or the non-linear patterns are not complex enough for the RBF kernel to offer a significant advantage over a linear approach with the current hyperparameters.
# *   All models showed very high recall, indicating their effectiveness in identifying actual positive cases (loan approvals).
#
# ### Insights or Next Steps
# *   Given the comparable performance, the Linear SVM model is the most practical choice for deployment due to its simplicity, ease of interpretation, and potentially lower computational cost.
# *   Further hyperparameter tuning could be explored for the Polynomial and RBF kernels to see if their performance can be improved to surpass the Linear kernel, particularly if more complex non-linear relationships are suspected within the data.

# %% [markdown]
# ## Analysis of Misclassifications
#
# Based on the Linear SVM model's performance:
#
# *   **Eligible customers rejected (False Negatives):** These are cases where the model predicted a loan rejection (`0`), but the actual `Loan_Status` was approval (`1`). Our model rejected **`{fn}`** eligible customers.
#
# *   **Risky customers approved (False Positives):** These are cases where the model predicted a loan approval (`1`), but the actual `Loan_Status` was rejection (`0`). Our model approved **`{fp}`** risky customers.
#
# ### Qualitative Analysis:
#
# 1.  **Is it worse to reject a genuine customer or approve a risky one?**
#     *   In a fintech loan approval scenario, it's generally **worse to approve a risky customer** (False Positive). Approving a risky customer directly leads to financial losses for the company due to potential defaults. While rejecting a genuine customer (False Negative) means lost potential revenue and a negative customer experience, the direct financial impact of a false positive is often higher and can jeopardize the company's financial stability in the long run. The high recall value (0.9875) for approved loans indicates that the model is very good at identifying actual approvals, which means it minimizes false negatives.
#
# 2.  **Which metric matters most in this business scenario?**
#     *   Both **Precision** and **Recall** are crucial, but their relative importance depends on the specific business priorities. Given the concern about approving risky customers:
#         *   **Precision** (0.7596) is highly important because it measures the proportion of predicted positive cases (approved loans) that were actually correct. A higher precision means fewer risky customers are approved, directly mitigating financial risk.
#         *   **Recall** (0.9875) is also very important because it measures the model's ability to identify all actual positive cases (genuine loan approvals). A high recall means fewer eligible customers are rejected, which is good for customer satisfaction and potential revenue.
#
#     *   In scenarios where minimizing financial losses from defaults is the paramount concern, **Precision** might be considered slightly more critical, as it directly relates to avoiding False Positives. However, a balanced approach is usually best. The current model shows a very high recall, which is excellent for not rejecting eligible customers, but its precision indicates there's still room to reduce the number of risky customers being approved. This suggests that further tuning or a different model might aim to improve precision without significantly sacrificing recall.

# %%
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix for the Linear SVM model
cm_linear = confusion_matrix(y_test, y_pred_linear)

# Assuming 'Loan_Status' 0 is 'N' (Rejected) and 1 is 'Y' (Approved)
# Confusion Matrix structure:
# [[True Negative, False Positive]
#  [False Negative, True Positive]]

tn, fp, fn, tp = cm_linear.ravel()

print(f"Confusion Matrix for Linear SVM:\n{cm_linear}")
print(f"\nNumber of eligible customers rejected (False Negatives): {fn}")
print(f"Number of risky customers approved (False Positives): {fp}")
# Out:
# Confusion Matrix for Linear SVM:
# [[18 25]
#  [ 1 79]]
#
# Number of eligible customers rejected (False Negatives): 1
# Number of risky customers approved (False Positives): 25

# %% [markdown]
# ## Analysis of Misclassifications
#
# Based on the Linear SVM model's performance:
#
# *   **Eligible customers rejected (False Negatives):** These are cases where the model predicted a loan rejection (`0`), but the actual `Loan_Status` was approval (`1`). Our model rejected **`{fn}`** eligible customers.
#
# *   **Risky customers approved (False Positives):** These are cases where the model predicted a loan approval (`1`), but the actual `Loan_Status` was rejection (`0`). Our model approved **`{fp}`** risky customers.
#
# ### Qualitative Analysis:
#
# 1.  **Is it worse to reject a genuine customer or approve a risky one?**
#     *   In a fintech loan approval scenario, it's generally **worse to approve a risky customer** (False Positive). Approving a risky customer directly leads to financial losses for the company due to potential defaults. While rejecting a genuine customer (False Negative) means lost potential revenue and a negative customer experience, the direct financial impact of a false positive is often higher and can jeopardize the company's financial stability in the long run. The high recall value (0.9875) for approved loans indicates that the model is very good at identifying actual approvals, which means it minimizes false negatives.
#
# 2.  **Which metric matters most in this business scenario?**
#     *   Both **Precision** and **Recall** are crucial, but their relative importance depends on the specific business priorities. Given the concern about approving risky customers:
#         *   **Precision** (0.7596) is highly important because it measures the proportion of predicted positive cases (approved loans) that were actually correct. A higher precision means fewer risky customers are approved, directly mitigating financial risk.
#         *   **Recall** (0.9875) is also very important because it measures the model's ability to identify all actual positive cases (genuine loan approvals). A high recall means fewer eligible customers are rejected, which is good for customer satisfaction and potential revenue.
#
#     *   In scenarios where minimizing financial losses from defaults is the paramount concern, **Precision** might be considered slightly more critical, as it directly relates to avoiding False Positives. However, a balanced approach is usually best. The current model shows a very high recall, which is excellent for not rejecting eligible customers, but its precision indicates there's still room to reduce the number of risky customers being approved. This suggests that further tuning or a different model might aim to improve precision without significantly sacrificing recall.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Apply PCA to reduce to 2 components for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_preprocessed)

# Split PCA data into training and testing sets (optional, but good practice)
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(
    X_pca, y, test_size=0.2, random_state=42
)

# Train a new RBF SVM on the 2-component PCA data
svm_rbf_pca = SVC(kernel='rbf', C=1, gamma='scale')
svm_rbf_pca.fit(X_train_pca, y_train_pca)

# Create a mesh to plot the decision boundary
x_min, x_max = X_pca[:, 0].min() - 1, X_pca[:, 0].max() + 1
y_min, y_max = X_pca[:, 1].min() - 1, X_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# Predict on the meshgrid points
Z = svm_rbf_pca.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary and the data points
plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.coolwarm)
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette='coolwarm', s=50, alpha=0.8)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('RBF SVM Decision Boundary on PCA Components')
plt.grid(True)
plt.show()

# %%
streamlit run app.py
# Out:
#   Cell In[30], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
